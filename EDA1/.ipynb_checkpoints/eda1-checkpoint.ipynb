# %% [markdown]
# <h1>EDA - Salarios</h1>
# <p>Análisis Exploratorio</p>
# <p>Junio 2026</p>

# %% [markdown]
# <h1>Configuración y carga</h1>

# %% [markdown]
# <h2>Importar librerias</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# <h2>Configuración general</h2>

# %%
# Mostrar todas las columnas
pd.set_option('display.max_columns', None)
# Redonder a dos decimales
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# <h2>Estilos en los gráficos</h2>

# %%
sns.set_theme(style='whitegrid', palette='Set2')
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# <h1>Carga del dataset</h1>

# %%
URL1 = './diabetes.csv'
URL2 = 'https://raw.githubusercontent.com/semilun4/EDA-Data-Science/refs/heads/main/Data/data_science.csv'


df = pd.read_csv(URL2)
print(' PRIMERAS 5 FILAS ')
df.head()
print(' MUESTRA ALEATORIA ')
df.sample(5, random_state=42)
print(' ÚLTIMAS 5 FILAS ')
df.tail()
# Out:
#  PRIMERAS 5 FILAS
#  MUESTRA ALEATORIA
#  ÚLTIMAS 5 FILAS
#                 timestamp     company     level              title  \
# 62637   9/9/2018 11:52:32      Google        T4  Software Engineer
# 62638   9/13/2018 8:23:32   Microsoft        62  Software Engineer
# 62639  9/13/2018 14:35:59        MSFT        63  Software Engineer
# 62640  9/16/2018 16:10:35  Salesforce  Lead MTS  Software Engineer
# 62641   1/29/2019 5:12:59       apple      ict3  Software Engineer
#
#        totalyearlycompensation           location  yearsofexperience  \
# 62637                   327000        Seattle, WA              10.00
# 62638                   237000        Redmond, WA               2.00
# 62639                   220000        Seattle, WA              14.00
# 62640                   280000  San Francisco, CA               8.00
# 62641                   200000      Sunnyvale, CA               0.00
#
#        yearsatcompany                             tag  basesalary  \
# ...

# %% [markdown]
# <h2>Tipos de datos y estructura</h2>

# %%
# Información del dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62642 entries, 0 to 62641
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                62642 non-null  str
#  1   company                  62637 non-null  str
#  2   level                    62519 non-null  str
#  3   title                    62642 non-null  str
#  4   totalyearlycompensation  62642 non-null  int64
#  5   location                 62642 non-null  str
#  6   yearsofexperience        62642 non-null  float64
#  7   yearsatcompany           62642 non-null  float64
#  8   tag                      61772 non-null  str
#  9   basesalary               62642 non-null  float64
#  10  stockgrantvalue          62642 non-null  float64
#  11  bonus                    62642 non-null  float64
#  12  gender                   43102 non-null  str
#  13  otherdetails             40134 non-null  str
# ...

# %%
# Tipos de datos por columna
print('=== TIPOS DE DATOS ===')
tipos = pd.DataFrame({
    'Columna'   : df.columns,
    'Tipo'      : df.dtypes.values,
    'No Nulos'  : df.notnull().sum().values,
    'Nulos'     : df.isnull().sum().values,
    '% Nulos'   : (df.isnull().sum().values / len(df) * 100).round(2)
})
tipos
# Out:
# === TIPOS DE DATOS ===
#                     Columna     Tipo  No Nulos  Nulos  % Nulos
# 0                 timestamp      str     62642      0     0.00
# 1                   company      str     62637      5     0.01
# 2                     level      str     62519    123     0.20
# 3                     title      str     62642      0     0.00
# 4   totalyearlycompensation    int64     62642      0     0.00
# 5                  location      str     62642      0     0.00
# 6         yearsofexperience  float64     62642      0     0.00
# 7            yearsatcompany  float64     62642      0     0.00
# 8                       tag      str     61772    870     1.39
# 9                basesalary  float64     62642      0     0.00
# 10          stockgrantvalue  float64     62642      0     0.00
# 11                    bonus  float64     62642      0     0.00
# 12                   gender      str     43102  19540    31.19
# 13             otherdetails      str     40134  22508    35.93
# ...
